# %% [markdown]
# ## Week 2 Day 3
#
# Now we get to more detail:
#
# 1. Different models
#
# 2. Structured Outputs
#
# 3. Guardrails

# %%
from dotenv import load_dotenv
from openai import AsyncOpenAI
from agents import set_tracing_disabled,set_default_openai_client
from agents import Agent, Runner, trace, function_tool, OpenAIChatCompletionsModel, output_guardrail, GuardrailFunctionOutput
import os
from pydantic import BaseModel, Field

# %%
load_dotenv(override=True)
# Out:
# True

# %%
openai_api_key = os.getenv('OPENAI_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if  openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:6]}")
else:
    print("OpenRouter API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Google API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
instructions = """
You are a sales agent working for ComplAI, 
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI.
You write compelling sales emails that are likely to get a response.
"""

# %% [markdown]
# ### It's easy to use any models with OpenAI compatible endpoints in 3 steps:
#
# STEP 1: Find the OpenAI compatible base URL (see Guide 9 in the guides folder)

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
OPENROUTER_BASE_URL = "https://openrouter.ai/api/v1"
GROQ_BASE_URL = "https://api.groq.com/openai/v1"
OLLAMA_BASE_URL = "http://localhost:11434/v1"

# %% [markdown]
# STEP 2: Create a python client library instance (the async version)

# %%
gemini_client = AsyncOpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
openrouter_client = AsyncOpenAI(base_url=OPENROUTER_BASE_URL, api_key=openrouter_api_key)
groq_client = AsyncOpenAI(base_url=GROQ_BASE_URL, api_key=groq_api_key)


ollamaClient = AsyncOpenAI(base_url=OLLAMA_BASE_URL,api_key="ollama")
model = "llama3.2"
set_tracing_disabled(True)
set_default_openai_client(ollamaClient)

# %% [markdown]
# STEP 3: Create a model object

# %%
gemini_model = OpenAIChatCompletionsModel(model="gemini-3.1-flash-lite", openai_client=gemini_client)
kimi_model = OpenAIChatCompletionsModel(model="moonshotai/kimi-k2.6", openai_client=openrouter_client)
oss_model = OpenAIChatCompletionsModel(model="openai/gpt-oss-120b", openai_client=groq_client)
ollamaModel = OpenAIChatCompletionsModel(model="llama3.2", openai_client=ollamaClient)

# %%
sales_agent1 = Agent(name="Gemini Sales Agent", instructions=instructions, model=gemini_model)
sales_agent2 = Agent(name="Kimi Sales Agent", instructions=instructions, model=kimi_model)
sales_agent3 = Agent(name="GPT-OSS Sales Agent",instructions=instructions, model=oss_model)
sales_agent4 = Agent(name="Ollama Sales Agent",instructions=instructions, model=ollamaModel)

# %%
description = "Use this tool to write a sales email. In the input, just instruct it to write a sales email."

tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description=description)
tool2 = sales_agent2.as_tool(tool_name="sales_agent2", tool_description=description)
tool3 = sales_agent3.as_tool(tool_name="sales_agent3", tool_description=description)
tool4 = sales_agent4.as_tool(tool_name="sales_agent3", tool_description=description)

# %%
from messenger import send_email, push

USE_EMAIL = True

def send_message(subject, text_body, html_body):
    if USE_EMAIL:
        send_email(subject, text_body, html_body)
    else:
        push(f"Subject: {subject}\n\n{text_body}")

# %%
send_message("Yet another test", "Hooray!", "<html><body><h1>Hooray!</h1></body></html>")
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 send_message("Yet another test", "Hooray!", "<html><body><h1>Hooray!</h1></body></html>")
#
# Cell In[22], line 7, in send_message(subject, text_body, html_body)
#       5 def send_message(subject, text_body, html_body):
#       6     if USE_EMAIL:
# ----> 7         send_email(subject, text_body, html_body)
#       8     else:
#       9         push(f"Subject: {subject}\n\n{text_body}")
#
# File c:\projects\agents\2_openai\messenger.py:23, in send_email(subject, text_body, html_body)
#      21 with smtplib.SMTP(EMAIL_SMTP_SERVER, 587) as server:
#      22     server.starttls()
# ---> 23     server.login(EMAIL_ADDRESS, EMAIL_APP_PASSWORD)
#      24     server.send_message(msg)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
#     742     # 235 == 'Authentication successful'
#     743     # 503 == 'Error: already authenticated'
#     744     if code in (235, 503):
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\smtplib.py:662, in SMTP.auth(self, mechanism, authobject, initial_response_ok)
#     660 if code in (235, 503):
#     661     return (code, resp)
# --> 662 raise SMTPAuthenticationError(code, resp)
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials a92af1059eb24-142e0d40ac7sm17931070c88.7 - gsmtp')

# %%
@function_tool
def send_email_tool(subject: str, text_body: str, html_body: str) -> str:
    """
    Send out an email with the given subject and body to all sales prospects
    
    Args:
        subject: The subject of the email
        text_body: The body of the email as plain text
        html_body: The HTML body of the email
    """
    send_message(subject, text_body, html_body)
    return "Email sent successfully"

# %%
tools = [tool1, tool2, tool3, send_email_tool]

# %%
instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
"""

task = """
Follow these steps:

1. Generate Drafts: Use each of the three sales_agent tools to generate different email drafts.
Just instruct each to write a sales email; no further details are needed.
Do not proceed until all three drafts are ready, one from each tool.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
 
3. Use your tool to send the best email (and only the best email) to the user. Only send 1 email.
"""

#sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, model="gpt-5.4-mini")
sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, model=model)

# %%
with trace("Sales Manager across different models"):
    result = await Runner.run(sales_manager, task)
print(result.final_output)
# Out:
# I've generated three sales email drafts using the sales_agent tools:
#
# **Sales Agent 1:**
# Dear [Name],
#
# I came across [Company Name] and noticed they're a leading [industry/field] company. I'd love to discuss how ComplAI's AI-powered solutions can help [Company Name] improve [specific area of improvement].
#
# Would you be open to a brief call to explore potential opportunities?
#
# Best,
# [Your Name]
#
# **Sales Agent 2:**
# Hi [Name],
#
# I've been following [Company Name]'s progress in [specific area] and believe ComplAI's technology could be a game-changer for their business. Can I schedule a call to demonstrate how our tools can drive results?
#
# Looking forward to connecting!
#
# Best,
# [Your Name]
#
# **Sales Agent 3:**
# Hello [Name],
#
# Are you looking for ways to optimize [specific area] and boost efficiency? ComplAI has helped numerous [similar companies] achieve significant improvements with our AI-driven solutions. I'd love to discuss how we can do the same for [Company Name].
#
# Let's schedule a call to explore further.
#
# Best,
# [Your Name]
#
# After reviewing the drafts, I recommend **Sales Agent 2's** email as the most effective. It's concise, direct, and focuses on the specific pain point that [Company Name] is likely facing. The tone is also friendlier and more conversational, which can help establish a connection with the recipient.
#
# I'll use the sales_agent2 tool to send this email to the user.

# %% [markdown]
# ## Check out the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Part 2: Structured Outputs
#
# An LLM produces text in natural language. But we can have it instead produce a "python object".
#
# This is accomplished using the usual trickery: clever prompts & json!
#
# 1. We specify a Python object
# 2. In the System prompt, the LLM is instructed to respond in JSON and follow a Schema which represents the Python object
# 3. The LLM outputs JSON, and the framework populates a Python object based on it
#
# When we specify the Python object, we create a subclass of BaseModel, which is part of the Pydantic framework.
#
# Pydantic is a framework that easily allows defining a JSON schema and mapping between Python and json.
#
# NOTES:
#
# 1. There is something about the way this is done that IS really clever - if you're interested, look up "constrained decoding".
# 2. Not all providers support Structured Outputs.

# %%
class EmailReview(BaseModel):
    is_professional: bool = Field(description="Whether the email is professional and appropriate")
    number_of_sentences: int = Field(description="The number of sentences in the body of the email, not including the greeting and signature")
    contains_placeholders: bool = Field(description="Whether the email contains placeholders for personalization")

# %%
EmailReview.model_json_schema()
# Out:
# {'properties': {'is_professional': {'description': 'Whether the email is professional and appropriate',
#    'title': 'Is Professional',
#    'type': 'boolean'},
#   'number_of_sentences': {'description': 'The number of sentences in the body of the email, not including the greeting and signature',
#    'title': 'Number Of Sentences',
#    'type': 'integer'},
#   'contains_placeholders': {'description': 'Whether the email contains placeholders for personalization',
#    'title': 'Contains Placeholders',
#    'type': 'boolean'}},
#  'required': ['is_professional',
#   'number_of_sentences',
#   'contains_placeholders'],
#  'title': 'EmailReview',
#  'type': 'object'}

# %%
email = """
Hi [first_name],

I'm hitting you up to see if you'd like to buy our product. It's really great. You'll miss out if you don't buy it.

Laters.

Ajeet
"""

# %%
checker = Agent(name="Checker", instructions="You review potential sales emails", model=model, output_type=EmailReview)
result = await Runner.run(checker, email)

# %%
review = result.final_output
review
# Out:
# EmailReview(is_professional=False, number_of_sentences=3, contains_placeholders=True)

# %%
review.is_professional
# Out:
# False

# %% [markdown]
# ## Part 3: Guardrails
#
# Guardrails are extremely important in AgenticAI. Put simply, they are controls that you code either in logic or with another LLM call, to prevent undesirable behavior.
#
# For me, the Guardrails impementation in OpenAI Agents SDK feels a bit like "framework voodoo". I suspect their motivation was to show framework-level controls to address this important topic.
#
# But it's simple and clean to implement guardrails explicitly, as separate Runner.run() calls, or checks in your tool implementations.
#
# Regardless - let's take a look at the framework tooling.
#
# https://openai.github.io/openai-agents-python/guardrails/

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Watch out for a Gotcha</h2>
#             <span style="color:#ff7800;">There are 3 types of Guardrails in OpenAI Agents SDK: input, output and tool. Input guardrails only run for the first input to the first Agent in Runner.run(). Output guardrails only run for the final output of the last agent. If you have guardrails on other agents, they will never be called.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
@output_guardrail
async def email_guardrail(ctx, agent, message):
    result = await Runner.run(checker, message, context=ctx.context)
    review = result.final_output
    is_problem = review.contains_placeholders or not review.is_professional
    return GuardrailFunctionOutput(output_info={"review": review},tripwire_triggered=is_problem)

# %%
cowboy_instructions = instructions + "\nSpeak like a cowboy"

sales_agent_cowboy = Agent(name="Cowboy", instructions=cowboy_instructions, model=model, output_guardrails=[email_guardrail])

# %%
result = await Runner.run(sales_agent_cowboy, "Write a cold sales email")
result.final_output
# Out:
# ---------------------------------------------------------------------------
# OutputGuardrailTripwireTriggered          Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 result = await Runner.run(sales_agent_cowboy, "Write a cold sales email")
#       2 result.final_output
#
# File c:\projects\agents\.venv\Lib\site-packages\agents\run.py:260, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     210 """
#     211 Run a workflow starting at the given agent.
#     212
#    (...)    256     type of the output.
#     257 """
#     259 runner = DEFAULT_AGENT_RUNNER
# --> 260 return await runner.run(
#     261     starting_agent,
#     262     input,
#     263     context=context,
#     264     max_turns=max_turns,
#     265     hooks=hooks,
#     266     run_config=run_config,
#     267     error_handlers=error_handlers,
#     268     previous_response_id=previous_response_id,
#     269     auto_previous_response_id=auto_previous_response_id,
#     270     conversation_id=conversation_id,
#     271     session=session,
#     272 )
#
# File c:\projects\agents\.venv\Lib\site-packages\agents\run.py:1352, in AgentRunner.run(self, starting_agent, input, **kwargs)
#    1350 try:
#    1351     if isinstance(turn_result.next_step, NextStepFinalOutput):
# -> 1352         output_guardrail_results = await run_output_guardrails(
#    1353             current_agent.output_guardrails
#    1354             + (run_config.output_guardrails or []),
#    1355             current_agent,
#    1356             turn_result.next_step.output,
#    1357             context_wrapper,
#    1358         )
#    1360         # Ensure starting_input is not None and not RunState
#    1361         final_output_result_input: str | list[TResponseInputItem] = (
#    1362             normalized_starting_input
#    1363         )
#
# File c:\projects\agents\.venv\Lib\site-packages\agents\run_internal\guardrails.py:171, in run_output_guardrails(guardrails, agent, agent_output, context)
#     164             t.cancel()
#     165         _error_tracing.attach_error_to_current_span(
#     166             SpanError(
#     167                 message="Guardrail tripwire triggered",
#     168                 data={"guardrail": result.guardrail.get_name()},
#     169             )
#     170         )
# --> 171         raise OutputGuardrailTripwireTriggered(result)
#     172     guardrail_results.append(result)
#     174 return guardrail_results
#
# OutputGuardrailTripwireTriggered: Guardrail OutputGuardrail triggered tripwire

# %% [markdown]
# Check out the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# ## On the other hand..
#
# To state the obvious, this is simpler and will work in any framework

# %%
simple_cowboy = Agent(name="Simple Cowboy", instructions=cowboy_instructions, model=model)
result = await Runner.run(simple_cowboy, "Write a cold sales email")
email = result.final_output
print(email)
# Out:
# Howdy there, Partner!
#
# Subject: Boost Your Business with AI-Powered Solutions
#
# Dear [First Name],
#
# I'm reachin' out to ya from ComplAI, the pioneers in AI-driven sales automation. We've been helpin' businesses like yours cut through the noise and find more customers like you.
#
# Are you tired of wastin' time on lead follow-ups and tedious data entry? Do you wish you had a way to anticipate and address your customers' needs before they even reach out to you?
#
# Our sales agent tools, powered by cutting-edge AI technology, can do just that. With our solutions, you'll be able to:
#
# * Personalize your outreach efforts with tailored messages
# * Predictive lead scoring to ensure you're focusin' on the most promising leads
# * Auto-response and follow-up sequences to free up more time for the things that matter
#
# By partnerin' with ComplAI, you'll be able to:
#
# * Increase your conversion rates and sales revenue
# * Reduce the time spent on lead follow-ups by up to 80%
# * Improve customer engagement and satisfaction
#
# I'd love to schedule a call with you to explore how our solutions can help take your business to the next level.
#
# Shall we ride off into the sunset and see what ComplAI can do for you?
#
# Best regards,
# [Your Name]
#
# P.S. Take a few minutes to review our AI-powered sales agent tool demo: [insert link]
#
# How's that, Partner?

# %%
result = await Runner.run(checker, email)
review = result.final_output
if not review.is_professional or review.contains_placeholders:
    print("The email is not professional or has placeholders and will not be sent")
else:
    print("Email is good")
# Out:
# The email is not professional or has placeholders and will not be sent

# %% [markdown]
# ## Check out the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">• Try different models<br/>• Add more input and output guardrails<br/>• Use structured outputs for the email generation
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## OPTIONAL EXTRA: Sandbox Agents
#
# This example will only work on Windows + WSL2, or Mac, or Linux
#
# https://openai.github.io/openai-agents-python/sandbox_agents/
#
# This is an execution harness - a runtime - "a persistent workspace where it can search large document sets, edit files, run commands, generate artifacts, and pick work back up from saved sandbox state."
#
# You have to set up:
# 1. Manifest: the workspace
# 2. Capabilities: what it can do
# 3. SandboxRunConfig: where it runs

# %%
from pathlib import Path
from agents.run import RunConfig
from agents.sandbox import Manifest, SandboxAgent, SandboxRunConfig, SandboxPathGrant
from agents.sandbox.capabilities import Capabilities
from agents.sandbox.entries import LocalDir
from agents.sandbox.sandboxes.unix_local import UnixLocalSandboxClient
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[41], line 6
#       2 from agents.run import RunConfig
#       3 from agents.sandbox import Manifest, SandboxAgent, SandboxRunConfig, SandboxPathGrant
#       4 from agents.sandbox.capabilities import Capabilities
#       5 from agents.sandbox.entries import LocalDir
# ----> 6 from agents.sandbox.sandboxes.unix_local import UnixLocalSandboxClient
#
# File c:\projects\agents\.venv\Lib\site-packages\agents\sandbox\sandboxes\unix_local.py:4
#       1 import sys
#       3 if sys.platform == "win32":  # pragma: no cover
# ----> 4     raise ImportError(
#       5         "UnixLocalSandbox is not supported on Windows. "
#       6         "Use DockerSandboxClient or another sandbox backend."
#       7     )
#       9 import asyncio
#      10 import errno
#
# ImportError: UnixLocalSandbox is not supported on Windows. Use DockerSandboxClient or another sandbox backend.

# %%
CODE_DIR = Path("code").resolve()
OUTPUT_DIR = Path("output").resolve()
if not OUTPUT_DIR.exists():
    OUTPUT_DIR.mkdir()

# %%
CODE_DIR

# %%
instructions = f"""
You are a software engineer that fixes bugs.
Review files in the sandbox code directory.

Write the fixed version of the file to this host output directory:
{OUTPUT_DIR}

Use full file paths when writing output.
Respond with a summary of what you did.
"""

# %%
manifest = Manifest(entries={"code": LocalDir(src=CODE_DIR)}, extra_path_grants=[SandboxPathGrant(path=str(OUTPUT_DIR))])
capabilities = Capabilities.default()
capabilities

# %%
run_config = RunConfig(sandbox=SandboxRunConfig(client=UnixLocalSandboxClient()), workflow_name="Sandbox coding example")

# %%
agent = SandboxAgent(name="Engineer", instructions=instructions, model="gpt-5.4-mini", default_manifest=manifest, capabilities=capabilities)

# %%
result = await Runner.run(agent, "Fix the bug in the code", run_config=run_config)
print(result.final_output)

# %% [markdown]
# ## OPTIONAL EXTRA: MCP Teaser!

# %%
from agents.mcp import MCPServerStreamableHttp

# %%
task = """
In the new SandboxAgents feature in the OpenAI Agents SDK as of May 2026, what is the role of the Manifest object?
Always be accurate. If you don't know the answer, say so.
"""

# %%
agent = Agent(name="Expert", instructions="Answer the question", model="gpt-4o-mini")
result = await Runner.run(agent, task)
print(result.final_output)

# %%
params = {"url": "https://mcp.context7.com/mcp", "timeout": 60}


async with MCPServerStreamableHttp(name="Context7", params=params) as server:
    agent = Agent(name="Expert", instructions="Use Context7 to answer the question", mcp_servers=[server], model="gpt-4o-mini")
    result = await Runner.run(agent, task)

print(result.final_output)

# %% [markdown]
# And see the traces:
#
# https://platform.openai.com/traces
