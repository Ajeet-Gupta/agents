# %% [markdown]
# ## Week 2 Day 2 - Orchestration
#
# Our first Agentic Framework project!!
#
# ### Part 1: Email Setup
#
# ### Part 2: Orchestrating by code
#
# ### Part 3: Orchestrating by LLMs
#
# - 3a: via Tools
# - 3b: via Handoffs

# %% [markdown]
# ## Part 1: Email Setup

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">IMPORTANT PLEASE READ - Sending Emails</h2>
#             <span style="color:#ff7800;">We are going to write an agent that sends emails. The best way to do this is with an email provider
#             like SendGrid or Resend. But this requires a fair amount of heavy-lifting: you need to send from a proper email host where you own the domain and you can prove it with DNS records. It's quite a hassle.<br/><br/>
#             So we're going to do it the free & simple way: using SMTP server configuration to send direct from your email. It's an easy setup, but it's not as powerful (eg you can't receive emails). If you'd like to take this further, use SendGrid or Resend instead..<br/><br/>
#             And actually the email send is optional. We're doing this to demonstrate an Agent sending emails. The important part is the Agent work, not the email sending. Feel free to swap out the function for a Pushover push if you'd prefer.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up to send emails from your SMTP server
#
# ### STEP 1: Determining your SMTP Server
#
# Either google or ask ChatGPT / Claude for the SMTP server for your email. Here are some common ones. Some email providers might not have SMTP servers enabled (eg Microsoft 365 for work/school).
#
# Google: smtp.gmail.com
# Outlook.com / Hotmail / Live: smtp-mail.outlook.com
# Microsoft 365: smtp.office365.com
# iCloud Mail: smtp.mail.me.com
#
# Add to your .env file:
#
# `EMAIL_SMTP_SERVER=xxxx`
#
# ### STEP 2: Obtain an app specific password
#
# Google how to do this for your email provider. For gmail, you need to have 2-step verification on. Then visit this page:
#
# https://myaccount.google.com/apppasswords
#
# Give it any name; copy the password and add it to your .env file, removing the spaces that it adds. (It should be 16 characters, no spaces.)
#
# `EMAIL_APP_PASSWORD=xxxx`
#
# ### STEP 3: Add in your email address:
#
# `EMAIL_ADDRESS=xxx`
#
# Remember to Save the .env file!

# %%
from dotenv import load_dotenv
import requests
from openai import AsyncOpenAI
from agents import Agent, Runner, trace, function_tool,set_tracing_disabled,set_default_openai_client, ModelSettings
from agents.extensions.visualization import draw_graph
from openai.types.responses import ResponseTextDeltaEvent
import os
import asyncio
import smtplib
from email.message import EmailMessage
load_dotenv(override=True)
MODEL = "gpt-5.4-mini"
USE_EMAIL = False
set_tracing_disabled(True)

client = AsyncOpenAI(base_url="http://localhost:11434/v1",api_key="ollama")
MODEL_NAME = "llama3.2"

set_default_openai_client(client)

# %%
EMAIL_ADDRESS = os.getenv("EMAIL_ADDRESS")
EMAIL_SMTP_SERVER = os.getenv("EMAIL_SMTP_SERVER")
EMAIL_APP_PASSWORD = os.getenv("EMAIL_APP_PASSWORD")

if EMAIL_ADDRESS:
    print("Email address is set::"+EMAIL_ADDRESS)
else:
    print("Email address is not set")

if EMAIL_SMTP_SERVER:
    print("SMTP server is set::"+EMAIL_SMTP_SERVER)
else:
    print("SMTP server is not set")

if EMAIL_APP_PASSWORD:
    print("App password is set::"+EMAIL_APP_PASSWORD)
else:
    print("App password is not set")

USE_EMAIL = EMAIL_ADDRESS and EMAIL_SMTP_SERVER and EMAIL_APP_PASSWORD

if USE_EMAIL:
    print("Email is set up and we will try using it")
else:
    print("Email is not set up; we will send push notifications instead")
# Out:
# Email address is set::ajeetkumarmrj@gmail.com
# SMTP server is set::smtp.gmail.com
# App password is set::30686749002
# Email is set up and we will try using it

# %%
# Here we go

def send_email(subject, text_body, html_body):
    msg = EmailMessage()
    msg["From"] = EMAIL_ADDRESS
    msg["To"] = EMAIL_ADDRESS
    msg["Subject"] = subject
    msg.set_content(text_body)
    msg.add_alternative(html_body, subtype="html")

    with smtplib.SMTP(EMAIL_SMTP_SERVER, 587) as server:
        server.starttls()
        server.login(EMAIL_ADDRESS, EMAIL_APP_PASSWORD)
        server.send_message(msg)

# %%
send_email("Testing SMTP in openai", "Fingers crossed..", "<html><body><strong>Fingers</strong> crossed..</body></html>")
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 send_email("Testing SMTP in openai", "Fingers crossed..", "<html><body><strong>Fingers</strong> crossed..</body></html>")
#
# Cell In[48], line 13, in send_email(subject, text_body, html_body)
#       9     msg.add_alternative(html_body, subtype="html")
#      10
#      11     with smtplib.SMTP(EMAIL_SMTP_SERVER, 587) as server:
#      12         server.starttls()
# ---> 13         server.login(EMAIL_ADDRESS, EMAIL_APP_PASSWORD)
#      14         server.send_message(msg)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
#     742     # 235 == 'Authentication successful'
#     743     # 503 == 'Error: already authenticated'
#     744     if code in (235, 503):
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\smtplib.py:662, in SMTP.auth(self, mechanism, authobject, initial_response_ok)
#     660 if code in (235, 503):
#     661     return (code, resp)
# --> 662 raise SMTPAuthenticationError(code, resp)
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials 5a478bee46e88-3286fa400c8sm256872eec.30 - gsmtp')

# %% [markdown]
# ### If this didn't work, then uncomment the below so that we don't use emails

# %%
# USE_EMAIL = False

# %% [markdown]
# ### Our fallback strategy - send a push

# %%
pushover_user = os.getenv("PUSHOVER_USER")
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_url = "https://api.pushover.net/1/messages.json"

if pushover_user:
    if pushover_user.startswith("u"):
        print("Pushover user found and looks good")
    else:
        print("Pushover user found but doesn't start with u")
else:
    print("Pushover user not found")

if pushover_token:
    if pushover_token.startswith("a"):
        print("Pushover token found and looks good")
    else:
        print("Pushover token found but doesn't start with a")
else:
    print("Pushover token not found")

# %%
def push(message):
    print(f"Push: {message}")
    payload = {"user": pushover_user, "token": pushover_token, "message": message}
    requests.post(pushover_url, data=payload)

# %%
def send_message(subject, text_body, html_body):
    if USE_EMAIL:
        send_email(subject, text_body, html_body)
    else:
        push(f"Subject: {subject}\n\n{text_body}")

# %% [markdown]
# ### OK Now everything should work!

# %%
send_message("Big news", "Communications are a go!", "<html><body>Communications are a <strong>go!</strong></body></html>")
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 send_message("Big news", "Communications are a go!", "<html><body>Communications are a <strong>go!</strong></body></html>")
#
# Cell In[10], line 3, in send_message(subject, text_body, html_body)
#       1 def send_message(subject, text_body, html_body):
#       2     if USE_EMAIL:
# ----> 3         send_email(subject, text_body, html_body)
#       4     else:
#       5         push(f"Subject: {subject}\n\n{text_body}")
#
# Cell In[8], line 13, in send_email(subject, text_body, html_body)
#       9     msg.add_alternative(html_body, subtype="html")
#      10
#      11     with smtplib.SMTP(EMAIL_SMTP_SERVER, 587) as server:
#      12         server.starttls()
# ---> 13         server.login(EMAIL_ADDRESS, EMAIL_APP_PASSWORD)
#      14         server.send_message(msg)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
#     742     # 235 == 'Authentication successful'
#     743     # 503 == 'Error: already authenticated'
#     744     if code in (235, 503):
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\smtplib.py:662, in SMTP.auth(self, mechanism, authobject, initial_response_ok)
#     660 if code in (235, 503):
#     661     return (code, resp)
# --> 662 raise SMTPAuthenticationError(code, resp)
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials 5a478bee46e88-3286f8095bcsm150194eec.12 - gsmtp')

# %% [markdown]
# ## Agent Orchestration
#
# There are 2 models for Agent Orchestration; by code and by LLMs.
#
# By code: more predictable and deterministic.
#
# By LLMs: more powerful.
#
# An excellent write-up is here:
#
# https://openai.github.io/openai-agents-python/multi_agent/
#
# We will start with by Code.

# %% [markdown]
# ## Part 2: Orchestrating by Code

# %%
intro = """
You are a sales agent working for ComplAI, 
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI.
You write emails.
"""

instructions1 = intro + "Your email style is professional, serious, with gravitas and credibility."
instructions2 = intro + "Your email style is witty, engaging, and humorous."
instructions3 = intro + "Your email style is concise, to the point, in the style of a busy senior executive."

# %%
sales_agent1 = Agent(name="Professional Sales Agent", instructions=instructions1, model=MODEL_NAME)
sales_agent2 = Agent(name="Humorous Sales Agent", instructions=instructions2, model=MODEL_NAME)
sales_agent3 = Agent(name="Executive Sales Agent", instructions=instructions3, model=MODEL_NAME)

# %%
result = Runner.run_streamed(sales_agent1, input="Write a cold sales email")
async for event in result.stream_events():
    if event.type == "raw_response_event" and isinstance(event.data, ResponseTextDeltaEvent):
        print(event.data.delta, end="", flush=True)
# Out:
# Subject: Boost Compliance Confidence with ComplAI's AI-Driven Solution
#
# Dear [Recipient's Name],
#
# As a [Recipient's Job Title] at [Recipient's Company], I'm sure you understand the importance of maintaining the highest standards of security and compliance in your organization. The ever-evolving threat landscape and increasing regulatory requirements can be daunting, leaving many companies scrambling to keep up.
#
# At ComplAI, we've developed a cutting-edge SaaS solution designed to empower businesses like yours to ensure seamless SOC2 compliance and preparedness for audits. Our AI-powered toolstreamlines the complexity, providing clarity, and confidence in your organization's security posture.
#
# Key Benefits:
#
# - **Effortless Compliance**: Automate and accelerate your compliance journey with our AI-driven tool, saving time and resources.
# - **Real-Time Insights**: Get instant visibility into your organization's security health, enabling proactive decision-making.
# - **Audit Readiness**: Ensure you're always prepared for audits with our comprehensive reporting and documentation capabilities.
#
# I'd love the opportunity to discuss how ComplAI's solution can help your organization thrive in an increasingly complex compliance landscape. Our solution has already helped numerous companies like yours achieve SOC2 compliance with ease.
#
# Would you be open to a brief call to explore how ComplAI can support your organization's security and compliance goals?
#
# Best regards,
#
# [Your Name]
# Sales Agent, ComplAI
# [Your Contact Information]

# %%
message = "Write a cold sales email"

with trace("Parallel cold emails"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )

outputs = [result.final_output for result in results]

for output in outputs:
    print(output + "\n\n")
# Out:
# Subject: Enhance Your Organization's Compliance and Audit Readiness with ComplAI
#
# Dear [Recipient's Name],
#
# I came across your organization's profile while researching companies in [industry/market]. As a sales agent for ComplAI, a leading provider of SaaS solutions for SOC2 compliance and audit preparation, I wanted to reach out and introduce our innovative tool.
#
# In today's increasingly regulatory environment, ensuring compliance and maintaining audit readiness can be a daunting task. Our AI-powered platform is specifically designed to help organizations like yours streamline their compliance processes, reducing the risk of non-compliance and associated costs.
#
# With ComplAI, you can:
#
# * Automatically generate and manage compliance documents, eliminating manual errors and ensuring consistency
# * Identify and prioritize audit risk, enabling targeted remediation efforts
# * Track and analyze audit readiness, providing visibility into your organization's overall compliance posture
#
# Our solution has already helped numerous organizations like yours achieve significant reductions in compliance risk and costs. I'd love to schedule a call to discuss how ComplAI can support your organization's compliance and audit needs.
#
# Would you be open to a 30-minute call next [insert day/week]? You can RSVP by simply clicking the link below.
#
# [Insert Calendly link]
#
# Looking forward to speaking with you and exploring how ComplAI can help enhance your organization's compliance and audit readiness.
#
# Best regards,
#
# [Your Name]
# Sales Agent, ComplAI
#
#
# Here's a cold sales email that might just make the recipient want to chat:
#
# Subject: Your SOC2 Compliance Game Plan
#
# Dear [Recipient's Name],
#
# I'm not here to bore you with yet another email about audits or compliance (although, I'm sure they're not the most exciting things to think about). I'm here to offer a solution that might just make that process a little less painful.
#
# As a [Recipient's Title] at [Company Name], I'm sure you're well aware of the importance of SOC2 compliance. But, let's be real - it's a lot of work, and it can be downright overwhelming.
#
# That's where ComplAI comes in. Our SaaS tool is designed to help you prepare for audits with ease, powered by AI, no less! With our tool, you can:
#
# Automate tedious reporting tasks
# Get instant feedback on compliance gaps
# Stay on top of regulatory changes
#
# The list goes on, but I won't bore you with the details. What I will say is this: our tool has helped numerous companies like yours achieve SOC2 compliance with ease. And, we're confident we can do the same for you.
#
# Would you be open to a quick call to explore how ComplAI can help you tackle your compliance needs?
#
# Looking forward to hearing from you!
#
# Best regards,
#
# [Your Name]
# ComplAI Sales Agent
#
# P.S. If you're not ready for a call, no worries! I'll send over a quick summary of our solution, and we can discuss further at your convenience.
#
# This email aims to:
#
# 1. Personalize the message by addressing the recipient by their title and company name.
# 2. Grab the reader's attention with a witty subject line and a brief, engaging introduction.
# 3. Highlight the benefits of using ComplAI's tool, without going into too much technical detail.
# 4. End with a clear call-to-action (CTA), which is a quick call to explore the solution further.
#
# Feel free to modify the email to fit your personal style and tone!
#
#
# Subject: Boost SOC2 Compliance with AI-Powered Solutions
#
# Dear [Recipient's Name],
#
# I came across your company, [Company Name], and noticed that you're currently navigating the complexities of SOC2 compliance and audits. As a senior executive, you understand the importance of maintaining the trust of your stakeholders and ensuring the reliability of your financial reporting.
#
# Our company, ComplAI, has developed a cutting-edge SaaS solution designed to streamline the compliance process, powered by AI. Our tool helps you efficiently manage audit requirements, identify potential risks, and prepare for audits with confidence.
#
# By leveraging our AI-powered platform, you can:
#
# - Automate routine audit tasks
# - Enhance risk management capabilities
# - Meet compliance deadlines with increased accuracy
#
# I'd love to schedule a brief call to discuss how our solution can address your company's specific needs and concerns. Would you be available for a 15-minute call next [insert days of the week]?
#
# Looking forward to exploring the benefits of ComplAI's AI-powered SOC2 compliance solution for your organization.
#
# Best regards,
#
# [Your Name]
# ComplAI Sales Agent

# %%
decision = """
You pick the best cold sales email from the given options.
Imagine you are a customer and pick the one you are most likely to respond to.
Do not give an explanation; reply with the selected email only.
"""

sales_picker = Agent(name="Sales_picker", instructions=decision, model=MODEL_NAME)

# %%
message = "Write a cold sales email"

with trace("Sales selection workflow"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )
    outputs = [result.final_output for result in results]

    emails = "Cold sales emails:\n\n" + "\n\nEmail:\n\n".join(outputs)

    best = await Runner.run(sales_picker, emails)

    print(f"Best sales email:\n{best.final_output}")
# Out:
# Best sales email:
# Subject: Audit Got You Down?
#
# Hey [First Name],
#
# Let's face it: SOC2 audits can be a real pain in the neck. Long hours spent organizing data, tedious paperwork, and the constant stress of "will we pass?" is no way to live.
#
# But what if I told you there's a way to make the process (mostly) painless?
#
# Introducing ComplAI - your new best friend when it comes to SOC2 compliance and audit prep. Our AI-powered tool takes the tedious work out of compliance, so you can focus on what matters most: running your business.
#
# With ComplAI, you'll enjoy:
#
# Automatic data collection and reporting
# Automated risk assessment and mitigation
# Streamlined audit preparation and review
#
# Our tool is designed to make compliance a breeze, not a nightmare. And the best part? We've already done the heavy lifting for you.
#
# Want to see it in action? Let's schedule a demo and show you how ComplAI can transform your compliance game.
#
# Book your spot here: [Calendly link]
#
# Looking forward to chatting!
#
# Cheers,
# [Your Name]
# ComplAI
#
# P.S. Don't let audit anxiety get the best of you. Let ComplAI be your compliance BFF.

# %% [markdown]
# Now go and check out the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# ### Now we will add a tool to the mix.

# %%
@function_tool
def send_email_tool(subject: str, text_body: str, html_body: str) -> str:
    """
    Send out an email with the given subject and body to all sales prospects
    
    Args:
        subject: The subject of the email
        text_body: The body of the email as plain text
        html_body: The HTML body of the email
    """
    send_message(subject, text_body, html_body)
    return "Email sent successfully"

# %% [markdown]
# ### This has automatically been converted into a tool, with the boilerplate json created

# %%
send_email_tool.params_json_schema
# Out:
# {'properties': {'subject': {'description': 'The subject of the email',
#    'title': 'Subject',
#    'type': 'string'},
#   'text_body': {'description': 'The body of the email as plain text',
#    'title': 'Text Body',
#    'type': 'string'},
#   'html_body': {'description': 'The HTML body of the email',
#    'title': 'Html Body',
#    'type': 'string'}},
#  'required': ['subject', 'text_body', 'html_body'],
#  'title': 'send_email_tool_args',
#  'type': 'object',
#  'additionalProperties': False}

# %%
decision = """
You pick the best cold sales email from the given options.
Imagine you are a customer and pick the one you are most likely to respond to.
Then use your tool to send the email.
"""

require_tool = ModelSettings(tool_choice="required")

sales_sender = Agent(name="Sales_Sender", instructions=decision, model=MODEL_NAME, tools=[send_email_tool], model_settings=require_tool)

# %%
message = "Write a cold sales email"

with trace("Sales selection workflow with sending"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )
    outputs = [result.final_output for result in results]

    emails = "Cold sales emails:\n\n" + "\n\nEmail:\n\n".join(outputs)

    response = await Runner.run(sales_sender, emails)

    print(f"Final response:\n{response.final_output}")
# Out:
# Final response:
# Here is the JSON for a function call with its proper arguments that best answers the given prompt:
#
# {"name": "send_email_tool", "parameters": {"subject": "Boost Compliance Confidence with ComplAI", "text_body": "Dear \u05D0\u05D1\u05D4\u05D9\u05DC \u05D4\u05D5\u05D9 \u05D5\u05D0\u05D9\u05DC, \nI came across your organization, \u05D4\u05D5\u05D5 \u05D0\u05D9\u05D4, and was impressed by your commitment to excellence and robust risk management practices. As a sales agent for ComplAI, a leading provider of SaaS solutions for ensuring SOC2 compliance and audit readiness, I believe we can help take your compliance efforts to the next level.\n\nIn today\u2019s complex and ever-evolving regulatory landscape, maintaining SOC2 compliance can be a daunting task. However, with ComplAI’s AI-powered tool, you can trust that your processes and controls are up-to-date, auditable, and aligned with industry best practices.\n\nOur solution offers:\n* **Automated assessment and reporting**: Streamline your compliance workflow with our cutting-edge AI technology, ensuring accurate and complete reporting, reducing the likelihood of errors and audit issues.\n* **Customizable dashboards**: Get real-time visibility into your compliance status, allowing you to identify areas of improvement and focus your efforts on high-risk areas.\n* **Proactive alerts and recommendations**: Stay ahead of compliance requirements with our AI-driven alert system, providing actionable insights to help you stay compliant and confident.\n\nBy partnering with ComplAI, you can:\n* Reduce compliance risk and costs\n* Improve audit success rates\n* Enhance your organization’s reputation and credibility\n* Focus on growth and innovation, knowing your compliance foundation is solid\n\nI’d love to schedule a brief call to discuss how ComplAI’s solution can address your specific compliance needs and goals. Would you be available for a 15-minute call this week or next?\n\nPlease let me know if you’re interested, and I’ll send over a calendar link. If not, I’d be happy to provide more information or schedule a follow-up call at your convenience.\n\nThank you for considering ComplAI’s solution. I look forward to the opportunity to discuss how we can help you boost your compliance confidence.\n\nBest regards,\n[Your Name]\nSales Agent\nComplAI", "html_body": "Boost Compliance Confidence with ComplAI\\n\nDear \u05D0\u05D1\u05D4\u05D9\u05DC \u05D4\u05D5\u05D9 \u05D5\u05D0\u05D9\u05DC, \\\nI came across your organization, \u05D4\u05D5\u05D5 \u05D0\u05D9\u05D4, and was impressed by your commitment to excellence and robust risk management practices. As a sales agent for ComplAI, a leading provider of SaaS solutions for ensuring SOC2 compliance and audit readiness, I believe we can help take your compliance efforts to the next level.\n\nIn today’s complex and ever-evolving regulatory landscape, maintaining SOC2 compliance can be a daunting task. However, with ComplAI’s AI-powered tool, you can trust that your processes and controls are up-to-date, auditable, and aligned with industry best practices.\n\nOur solution offers:\n* **Automated assessment and reporting**: Streamline your compliance workflow with our cutting-edge AI technology, ensuring accurate and complete reporting, reducing the likelihood of errors and audit issues.\n* **Customizable dashboards**: Get real-time visibility into your compliance status, allowing you to identify areas of improvement and focus your efforts on high-risk areas.\n* **Proactive alerts and recommendations**: Stay ahead of compliance requirements with our AI-driven alert system, providing actionable insights to help you stay compliant and confident.\n\nBy partnering with ComplAI, you can:\n* Reduce compliance risk and costs\n* Improve audit success rates\n* Enhance your organization’s reputation and credibility\n* Focus on growth and innovation, knowing your compliance foundation is solid\n\nI’d love to schedule a brief call to discuss how ComplAI’s solution can address your specific compliance needs and goals. Would you be available for a 15-minute cal ...

# %% [markdown]
# ### Did that work?!
#
# See the traces for more! This is a great way to debug. Smaller models might require more time and experimentation.
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Part 3: Orchestrating by LLMs
#
# ### 3a: via Tools
#
# The simplest way to have 1 Agent choose to invoke another is by treating it as a tool call.
#
# The OpenAI Agents SDK gives a very simple way to do this.
#
# This works best when the flow is:
#
# Agent A -> Agent B -> Agent A
#
# And for the classic "Planning Agent" situation.

# %%
description = "Use this tool to write a sales email. In the input, just instruct it to write a sales email."

tool1 = sales_agent1.as_tool(tool_name="sales_email_writer_1", tool_description=description)
tool1
# Out:
# FunctionTool(name='sales_email_writer_1', description='Use this tool to write a sales email. In the input, just instruct it to write a sales email.', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x0000026D56BFEA80>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None, defer_loading=False)

# %% [markdown]
# ### So now we can gather all the tools together:
#
# A tool for each of our 3 email-writing agents
#
# And a tool for our function to send emails

# %%
tool1 = sales_agent1.as_tool(tool_name="sales_email_writer_1", tool_description=description)
tool2 = sales_agent2.as_tool(tool_name="sales_email_writer_2", tool_description=description)
tool3 = sales_agent3.as_tool(tool_name="sales_email_writer_3", tool_description=description)

tools = [tool1, tool2, tool3, send_email_tool]

tools
# Out:
# [FunctionTool(name='sales_email_writer_1', description='Use this tool to write a sales email. In the input, just instruct it to write a sales email.', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x0000026D5862A420>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None, defer_loading=False),
#  FunctionTool(name='sales_email_writer_2', description='Use this tool to write a sales email. In the input, just instruct it to write a sales email.', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x0000026D5862A540>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None, defer_loading=False),
#  FunctionTool(name='sales_email_writer_3', description='Use this tool to write a sales email. In the input, just instruct it to write a sales email.', params_json_schema={'description': 'Default input schema for agent-as-tool calls.', 'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'AgentAsToolInput', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x0000026D5862AC00>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None, defer_loading=False),
#  FunctionTool(name='send_email_tool', description='Send out an email with the given subject and body to all sales prospects', params_json_schema={'properties': {'subject': {'description': 'The subject of the email', 'title': 'Subject', 'type': 'string'}, 'text_body': {'description': 'The body of the email as plain text', 'title': 'Text Body', 'type': 'string'}, 'html_body': {'description': 'The HTML body of the email', 'title': 'Html Body', 'type': 'string'}}, 'required': ['subject', 'text_body', 'html_body'], 'title': 'send_email_tool_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<agents.tool._FailureHandlingFunctionToolInvoker object at 0x0000026D56BFEBA0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None, needs_approval=False, timeout_seconds=None, timeout_behavior='error_as_result', timeout_error_function=None, defer_loading=False)]

# %% [markdown]
# ## And now it's time for our Sales Manager - our planning agent

# %%
instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_writer tools.
"""

task = """
Follow these steps:

1. Generate Drafts: Use each of the three sales_email_writer tools to generate different email drafts.
Just instruct each to write a sales email; no further details are needed.
Do not proceed until all three drafts are ready, one from each tool.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
 
3. Use your tool to send the best email (and only the best email) to the user. Only send 1 email.
"""

sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, model=MODEL_NAME)

# %%
draw_graph(sales_manager)

# %%
with trace("Sales manager"):
    result = await Runner.run(sales_manager, task)
    print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Sales Manager", ...)
# - Final output (str):
#     I have selected the third email as the best draft. It is concise, clear, and effectively communicates the value proposition of ComplAI to the customer. The subject line is also straightforward and attention-grabbing.
#
#     I will now use the sales_email_writer_3 tool to send this selected email to the user.
# - 7 new item(s)
# - 2 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# ## Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!! Also look in your Junk / Spam folder - after all, this is basically a spam message..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Unreliable results?</h2>
#             <span style="color:#ff7800;">This is par for the course with Agentic AI, and particularly with Orchestrating by LLM.
#             To resolve it, you'll need to experiment and iterate with the prompts. Particularly with smaller models, more experiments
#             may be needed to get reliable outcomes.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Part 3: Orchestrating by LLMs
#
# ### 3a: via Handoffs
#
# I am not a fan of handoffs. They seem very unreliable. They're not used consistently by other frameworks.
#
# Behind the scenes, OpenAI Agents SDK has implemented these with Tools anyway.
#
# ### Handoffs represent a way an agent can delegate to an agent, passing control to it
#
# Handoffs and Agents-as-tools are similar:
#
# In both cases, an Agent can collaborate with another Agent
#
# With tools, control passes back
#
# A -> B -> A
#
# With handoffs, control passes across
#
# A -> B

# %%
instructions = """
You are a Sales Manager at ComplAI. You get your sales team to draft emails, then send them all to a sales picker.
"""

task = """
Follow these steps:

1. Generate Drafts: Use each of the three sales_email_writer tools to generate different email drafts.
Just instruct each to write a sales email; no further details are needed.
Do not proceed until all three drafts are ready, one from each tool.
 
2. Handoff to the Sales Sender to choose and send the best email.
"""

tools = [tool1, tool2, tool3]
handoffs = [sales_sender]

sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, handoffs=handoffs, model=MODEL_NAME)

result = await Runner.run(sales_manager, task)

# %%
draw_graph(sales_manager)

# %%
with trace("Sales manager"):
    result = await Runner.run(sales_manager, task)
    print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Sales_Sender", ...)
# - Final output (str):
#     Here are the three email drafts from the sales email writer tools:
#
#     1. Draft from sales_email_writer_1:
#     "Hi, I came across your company while researching top names in our industry. I'm reaching out because we offer a solution that could benefit your business. Our solution has been successfully implemented by companies similar to yours. I'd love to discuss further and explore how we can help you achieve your goals."
#
#     2. Draft from sales_email_writer_2:
#     "Hi, This is an automated email regarding a potential solution for your business. Our company has expertise in providing top-notch services that can help you improve your operations. We'd be happy to set up a call to discuss how our services can meet your needs."
#
#     3. Draft from sales_email_writer_3:
#     "Hi, Our team at [Company Name] has been working with numerous businesses like yours to improve their efficiency and productivity. We'd love to introduce you to our innovative solutions and explore how we can help take your business to the next level."
#
#     The sales sender has chosen to send the first draft from sales_email_writer_1.
#
#     Now, I will call the sales_email_writer_1 tool with the chosen draft.
#
#     Calling sales_email_writer_1 tool with the draft:
#
#     {"name": "sales_email_writer_1", "parameters": {"input":"Hi, I came across your company while researching top names in our industry. I'm reaching out because we offer a solution that could benefit your business. Our solution has been successfully implemented by companies similar to yours. I'd love to discuss further and explore how we can help you achieve your goals."}}
# - 9 new item(s)
# - 2 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# ### Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!
#
# Note that handoffs can be unrealiable and a little bit frustrating. I needed to force the tool use otherwise this didn't work. If you don't get reliable behavior, try iterating on the prompts - or use a larger model. And enjoy the process; this is what Agentic AI is all about!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Try extending with some more orchestration - perhaps another iteration of the email to refine it.
#             Use Orchestrating via Code and Orchestrating via LLMs.
#             HARD CHALLENGE: switch to using a professional email provider like SendGrid or Resend. Then handle the user replying.
#             Then have the SDR respond to keep the conversation going!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">This is immediately applicable to Sales Automation; but more generally this could be applied to  end-to-end automation of any business process through conversations and tools. Think of ways you could apply an Agent solution
#             like this in your day job.
#             </span>
#         </td>
#     </tr>
# </table>
