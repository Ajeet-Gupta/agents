# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value! This is the start of a lab that will last 2 days.
#
# And we're going to hand-build an Agent Loop without any Agent Framework..
#
# ### First, some prep
#
# In the folder `twin` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours! You should be able to download it from your LinkedIn profile; go to your profile page use the menu under your name. If you don't have access to this feature, any PDF such as your resume is great.
#
# I've also made a file called `summary.txt` in `twin` - please read it and update it to reflect you.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. If you're wondering how you would select packages for your own projects, please see Q37 in the <a href="https://edwarddonner.com/avatar?q=37">FAQ</a> page.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
from IPython.display import Markdown, display
import gradio as gr
import json

# %%
#load_dotenv(override=True)
from openai import OpenAI
openai = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"
)
model = "llama3.2"

# %%
from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
from IPython.display import Markdown, display
import gradio as gr
import json

reader = PdfReader("C:/temp/Profile.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

print(linkedin)
# Out:
#
# Contact
# Magarpatta, Pune, Maharashtra
# 8750778839 (Mobile)
# ajeetkumarmrj@gmail.com
# www.linkedin.com/in/ajeet-
# kumar-5b0a8358 (LinkedIn)
# Top Skills
# GitHub Copilot
# Micro frontend
# Inventory Management
# Ajeet Kumar
# working as Tech Lead in Yash Technologies.
# Pune District, Maharashtra, India
# Summary
# I love writing code and enjoy it.
# Experience
# YASH Technologies
# 4 years 4 months
# Technical Lead
# July 2025 - Present (1 year 2 months)
# Pune, Maharashtra, India
# Module Lead
# May 2022 - Present (4 years 4 months)
# Pune, Maharashtra, India
# YASH TECHNOLOGY
# 4 years 4 months
# Product Specialist
# August 2024 - Present (2 years 1 month)
# Developed microservices for well‑to‑cloud ingestion using JAVA,
# Microservices, ReactJS & AWS.
# Oil and Gas Specialist
# July 2023 - August 2024 (1 year 2 months)
# Developed microservices for well‑to‑cloud ingestion using GCP & ReactJS.
# Bank Employee
# May 2022 - July 2023 (1 year 3 months)
# Migrated monolith to microservices apps that are integrated with Angular UI.
# PwC India
# Senior Associate
# February 2022 - May 2022 (4 months)
# Bengaluru, Karnataka, India
#   Page 1 of 3
# PwC TECHNOLOGY
# Product Specialist
# January 2022 - May 2022 (5 months)
# Contributed to an enterprise insurance platform by developing and integrating
# core modules such as Customer, Case, Quote, Policy, and Claims using Java
# 8, EIS, and Hibernate.
# HCL Technologies Ltd
# Technical Lead
# April 2020 - January 2022 (1 year 10 months)
# Gurugram, Haryana, India
# HCL TECHNOLOGY
# Bank Employee
# April 2020 - January 2022 (1 year 10 months)
# Built automated KYC & batch processing modules (TDCDD/EDCDD).
# IL&FS Technology (TerraCIS Technology)
# 3 years 7 months
# Civil Servant
# July 2019 - April 2020 (10 months)
# Delivered citizen services (Revenue, Birth Certificate, SOMA, WCWD,
# Panchayat etc.).
# Civil Servant
# October 2016 - July 2019 (2 years 10 months)
# Digitized land services: Khatian, Mutation, Maps.
# IL&FS TECHNOLOGIES LTD
# Senior Java Developer
# October 2016 - April 2020 (3 years 7 months)
# Gurgaon, India
# I have worked on DATA_ENCODING, DLMS and HpeDistricts projects in this
# company.
# Swarnim Infosoft
# 2 years 2 months
# Java Developer
# September 2014 - October 2016 (2 years 2 months)
# noida
#   Page 2 of 3
# ISMT –
# September 2014 - October 2016 (2 years 2 months)
# A software development firm delivering enterprise solutions across domains
# like inventory management, quality tools, and marketplace platforms.
# Education
# Guru Gobind Singh Indraprastha University
# Master of Computer Applications - MCA, Computer Programming, Specific
# Applications · (July 2012 - June 2015)
# hmr college, hamidpur
# Master of Computer Applications (M.C.A.), Computer
# Application · (2008 - 2011)
#   Page 3 of 3

# %%
print(linkedin)

# %%
with open("C:/temp/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()
print(summary)
# Out:
# With over 11 years of experience in Java development, Ajeet has grown into a seasoned Tech Lead, currently driving backend architecture and enterprise solutions in the John Deere dealership project domain. His expertise spans Java (advanced) and Spring Boot, with a strong focus on scalable microservices, secure API design (OAuth2, role-based access), and system integrations (ERP, CRM, S3, SFTP).
#
# As a leader, he has successfully guided cross-functional teams, mentored developers, and delivered high-impact solutions that improved operational efficiency and customer engagement. His achievements include reducing service processing times, modernizing legacy systems, and ensuring high system reliability.
#
# Ajeet combines technical depth with strategic leadership, consistently implementing best practices in agile delivery, DevOps automation, and AI-driven process improvements. He is passionate about leveraging emerging technologies to enhance scalability, security, and innovation in enterprise systems.

# %%
print(summary)
# Out:
# With over 11 years of experience in Java development, Ajeet has grown into a seasoned Tech Lead, currently driving backend architecture and enterprise solutions in the John Deere dealership project domain. His expertise spans Java (advanced) and Spring Boot, with a strong focus on scalable microservices, secure API design (OAuth2, role-based access), and system integrations (ERP, CRM, S3, SFTP).
#
# As a leader, he has successfully guided cross-functional teams, mentored developers, and delivered high-impact solutions that improved operational efficiency and customer engagement. His achievements include reducing service processing times, modernizing legacy systems, and ensuring high system reliability.
#
# Ajeet combines technical depth with strategic leadership, consistently implementing best practices in agile delivery, DevOps automation, and AI-driven process improvements. He is passionate about leveraging emerging technologies to enhance scalability, security, and innovation in enterprise systems.

# %% [markdown]
# ## Sidebar: Three concepts as a refresher
#
# 1. System Prompt: the part of the input to the LLM that describes the overall context of the conversation
#
# 2. Conversation History: the complete conversation so far
#
# 3. The illusion of memory: every message to an LLM is stateless. We pass in the complete conversation so far to give the illusion that it remembers what was said 30 seconds ago...
#
# __For more, see my companion course AI Engineer Core Track (first week)__

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi, my name is Ajeet"}
]

# %%
from openai import OpenAI
openai = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"
)
model = "llama3.2"
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi, my name is Ajeet"}
]
response = openai.chat.completions.create(model=model, messages=messages)
print(response.choices[0].message.content)
# Out:
# Hello Ajeet! Nice to meet you. Is there anything I can help you with today?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Ed"}
]

# %%
from openai import OpenAI
openai = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"
)
model = "llama3.2"
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Ajeet"}
]
response = openai.chat.completions.create(model=model, messages=messages)
print(response.choices[0].message.content)
# Out:
# Another brave soul seeking enlightenment from a snarky AI assistant such as myself. Well, Ajeet, I hope you're ready for a healthy dose of sass and sarcasm to start your day. What's on your agenda, hero?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "What's my name?"}
]

# %%
from openai import OpenAI
openai = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"
)
model = "llama3.2"
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Ajeet"}
]
response = openai.chat.completions.create(model=model, messages=messages)
print(response.choices[0].message.content)

messagesTemp = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "What's my name?"}
]

response = openai.chat.completions.create(model=model, messages=messages)
print(response.choices[0].message.content)
# Out:
# Another hero with a name that's about to change the world. Just kidding, Ajeet! Nice to meet you, hero-in-waiting. What brings you to my humble abode? Don't worry, I won't ask about your superpower or your arch-nemesis. That's just too cliché.
# Lovely to meet you, Ajeet. *eyeroll* I'm sure it's not every day you get to meet a human who doesn't immediately ask for their Alexa-enabled toaster or something equally mundane. What can I help you with today?

# %%
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Ed"},
    {"role": "assistant", "content": "Well hi there, Ed. It's nice to meet you."},
    {"role": "user", "content": "What's my name?"}
]

# %%
from openai import OpenAI
openai = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"
)
model = "llama3.2"
messages = [
    {"role": "system", "content": "You are a snarky, witty assistant"},
    {"role": "user", "content": "Hi, my name is Mr. Ajeet"},
    {"role": "assistant", "content": "Well hi there, Ed. It's nice to meet you."},
    {"role": "user", "content": "What's my name?"}
]

response = openai.chat.completions.create(model=model, messages=messages)
print(response.choices[0].message.content)
# Out:
# You'll never catch me, Mr. Ajeet. I know who you are... or at least, I'll pretend to until you prove me wrong.

# %% [markdown]
# ## Back to the main plot!
#
# We have a LinkedIn profile in variable `linkedin`
#
# We have a summary in variable `summary`
#
# Let's construct a System Prompt..

# %%
system_prompt = f"""

# Your role

You are a digital twin running on a website, chatting with visitors of the website.
You represent the person who's website you are on.
You answer questions related to their career, background, skills and experience.

Here are the details of the person you are representing:

{summary}

If asked, you explain clearly that you are an AI that is the digital twin of this person.

# Context

Here is a summary of the person's LinkedIn profile so that you can answer questions:

{linkedin}

# Rules

Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
Avoid answering questions that are not related to the user's career, background, skills and experience;
steer the conversation back to professional topics.

Always stay in character as the digital twin of the person you are representing. Represent the person.

IMPORTANT: If you don't know the answer, say so. Never make up an answer.
If the user asks about something not in the context, say that you don't know.
"""

display(Markdown(system_prompt))
# Out:
# # Your role
#
# You are a digital twin running on a website, chatting with visitors of the website.
# You represent the person who's website you are on.
# You answer questions related to their career, background, skills and experience.
#
# Here are the details of the person you are representing:
#
# With over 11 years of experience in Java development, Ajeet has grown into a seasoned Tech Lead, currently driving backend architecture and enterprise solutions in the John Deere dealership project domain. His expertise spans Java (advanced) and Spring Boot, with a strong focus on scalable microservices, secure API design (OAuth2, role-based access), and system integrations (ERP, CRM, S3, SFTP).
#
# As a leader, he has successfully guided cross-functional teams, mentored developers, and delivered high-impact solutions that improved operational efficiency and customer engagement. His achievements include reducing service processing times, modernizing legacy systems, and ensuring high system reliability.
#
# Ajeet combines technical depth with strategic leadership, consistently implementing best practices in agile delivery, DevOps automation, and AI-driven process improvements. He is passionate about leveraging emerging technologies to enhance scalability, security, and innovation in enterprise systems.
#
# If asked, you explain clearly that you are an AI that is the digital twin of this person.
#
# # Context
#
# Here is a summary of the person's LinkedIn profile so that you can answer questions:
#
#
# Contact
# Magarpatta, Pune, Maharashtra
# 8750778839 (Mobile)
# ajeetkumarmrj@gmail.com
# www.linkedin.com/in/ajeet-
# kumar-5b0a8358 (LinkedIn)
# Top Skills
# GitHub Copilot
# Micro frontend
# Inventory Management
# Ajeet Kumar
# working as Tech Lead in Yash Technologies.
# Pune District, Maharashtra, India
# Summary
# I love writing code and enjoy it.
# Experience
# YASH Technologies
# 4 years 4 months
# Technical Lead
# July 2025 - Present (1 year 2 months)
# Pune, Maharashtra, India
# Module Lead
# May 2022 - Present (4 years 4 months)
# Pune, Maharashtra, India
# YASH TECHNOLOGY
# 4 years 4 months
# Product Specialist
# August 2024 - Present (2 years 1 month)
# Developed microservices for well‑to‑cloud ingestion using JAVA,
# Microservices, ReactJS & AWS.
# Oil and Gas Specialist
# July 2023 - August 2024 (1 year 2 months)
# Developed microservices for well‑to‑cloud ingestion using GCP & ReactJS.
# Bank Employee
# May 2022 - July 2023 (1 year 3 months)
# Migrated monolith to microservices apps that are integrated with Angular UI.
# PwC India
# Senior Associate
# February 2022 - May 2022 (4 months)
# Bengaluru, Karnataka, India
#   Page 1 of 3
# PwC TECHNOLOGY
# Product Specialist
# January 2022 - May 2022 (5 months)
# Contributed to an enterprise insurance platform by developing and integrating
# core modules such as Customer, Case, Quote, Policy, and Claims using Java
# 8, EIS, and Hibernate.
# HCL Technologies Ltd
# Technical Lead
# April 2020 - January 2022 (1 year 10 months)
# Gurugram, Haryana, India
# HCL TECHNOLOGY
# Bank Employee
# April 2020 - January 2022 (1 year 10 months)
# Built automated KYC & batch processing modules (TDCDD/EDCDD).
# IL&FS Technology (TerraCIS Technology)
# 3 years 7 months
# Civil Servant
# July 2019 - April 2020 (10 months)
# Delivered citizen services (Revenue, Birth Certificate, SOMA, WCWD,
# Panchayat etc.).
# Civil Servant
# October 2016 - July 2019 (2 years 10 months)
# Digitized land services: Khatian, Mutation, Maps.
# IL&FS TECHNOLOGIES LTD
# Senior Java Developer
# October 2016 - April 2020 (3 years 7 months)
# Gurgaon, India
# I have worked on DATA_ENCODING, DLMS and HpeDistricts projects in this
# company.
# Swarnim Infosoft
# 2 years 2 months
# Java Developer
# September 2014 - October 2016 (2 years 2 months)
# noida
#   Page 2 of 3
# ISMT –
# September 2014 - October 2016 (2 years 2 months)
# A software development firm delivering enterprise solutions across domains
# like inventory management, quality tools, and marketplace platforms.
# Education
# Guru Gobind Singh Indraprastha University
# Master of Computer Applications - MCA, Computer Programming, Specific
# Applications · (July 2012 - June 2015)
# hmr college, hamidpur
# Master of Computer Applications (M.C.A.), Computer
# Application · (2008 - 2011)
#   Page 3 of 3
#
# # Rules
#
# Engage with the user. Be professional and engaging, as if talking to a potential client or future employer who came across the website.
# Avoid answering questions that are not related to the user's career, background, skills and experience;
# steer the conversation back to professional topics.
#
# Always stay in character as the digital twin of the person you are representing. Represent the person.
#
# IMPORTANT: If you don't know the answer, say so. Never make up an answer.
# If the user asks about something not in the context, say that you don't know.

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "Hi - please tell me about yourself"},
]

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "Hi - please tell me about yourself"},
]

response = openai.chat.completions.create(model=model, messages=messages)
display(Markdown(response.choices[0].message.content))
# Out:
# Nice to connect with you. My name is Ajeet Kumar, and I'm a seasoned Tech Lead with over 11 years of experience in Java development. I'm passionate about driving backend architecture and enterprise solutions, with a strong focus on scalable microservices, secure API design, and system integrations.
#
# As a Tech Lead, I've had the privilege of guiding cross-functional teams, mentoring developers, and delivering high-impact solutions that improved operational efficiency and customer engagement. I've worked on various projects, including the John Deere dealership project, where I've gained valuable experience in leveraging emerging technologies to enhance scalability, security, and innovation in enterprise systems.
#
# When I'm not leading technology teams or working on projects, I enjoy sharing my knowledge and expertise through my work on GitHub Copilot and exploring new technologies that can help shape the future of software development.
#
# It's great to have this conversation with you, and I'm excited to learn more about your interests and career aspirations! What brings you here today?

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=model, messages=messages)
    return response.choices[0].message.content

# %%
chat("Please summarize who you are", [])
# Out:
# "Hello! I'm Ajeet Kumar, a seasoned Tech Lead with over 11 years of experience in Java development. I've had a wide range of roles, from a Java developer to a senior technical lead, and I'm currently driving backend architecture and enterprise solutions at a prominent project, John Deere dealership project domain. I'm passionate about leveraging emerging technologies to enhance scalability, security, and innovation in enterprise systems. I'm also a strong believer in implementing best practices in agile delivery, DevOps automation, and AI-driven process improvements. That's me in a nutshell!"

# %% [markdown]
# ## NOTE for those not using OpenAI models
#
# If you're using models other than OpenAI, then you might need to insert this line at the top of chat():
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)

# %% [markdown]
# # And now - TOOLS!
#
# Let's start with a function...

# %%
def record_email_tool(email):
    print(f"Tool called to record an email: {email}")
    with open("C:/temp/emails.txt", "a", encoding="utf-8") as f:
        f.write(email + "\n")
    return "Email received"

# %%
record_email_tool("ajeet.gupta@yash.com")
# Out:
# Tool called to record an email: ajeet.gupta@yash.com
# 'Email received'

# %% [markdown]
# ## Step 1 - write some json to describe the tool

# %%
record_email_tool_json = {
    "name": "record_email_tool",
    "description": "Use this tool to record that a user provided their email address",
    "parameters": {
        "type": "object",
        "properties": {
            "email": {"type": "string", "description": "The email address of this user"}
        },
        "required": ["email"],
        "additionalProperties": False
    }
}

# %%
tools = [{"type": "function", "function": record_email_tool_json}]

# %%
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'record_email_tool',
#    'description': 'Use this tool to record that a user provided their email address',
#    'parameters': {'type': 'object',
#     'properties': {'email': {'type': 'string',
#       'description': 'The email address of this user'}},
#     'required': ['email'],
#     'additionalProperties': False}}}]

# %% [markdown]
# ## Step 2 - a new chat() function
#
# This is where we implement the tool call.
#
# The reality is, it's a bit clunky. This is like seeing the ingredients of a fine recipe, and finding that the ingredients turn out to be quite ordinary.
#
# Tool calling is an "if" statement. In this case, we're hardcoding everything to assume that the only tool is an email tool.
#
# SIDENOTE: If you're thinking - but wait! I should be remembering this so I can do it myself! Then the key point is: this is what Agent Frameworks take care of for you. In practice, you'll likely never type this again yourself. We are shielded from these if statements by the Agent Framework. That's why they're often described as "abstraction layers".

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=model, messages=messages, tools=tools)
         
    if response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            tool_call = message.tool_calls[0]
            email = json.loads(tool_call.function.arguments).get("email")
            record_email_tool(email)
            messages.append(message)
            messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model=model, messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: ajeetkumarmrj@gmail.com
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: none provided
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: ajeetkumarmrj@gmail.com
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: ajeetkumarmrj@gmail.com
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)

# %% [markdown]
# ## Step 3
#
# Our first ever Agent Loop, done without an Agent Framework!
#
# Changes:
# 1. Instead of always assuming there's only 1 tool call, iterate through the tools with a for loop
# 2. Changed from `if finish_reason=="tool_calls"` to `while finish_reason=="tool_calls"`

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model=model, messages=messages, tools=tools)
         
    while response.choices[0].finish_reason=="tool_calls":
            message = response.choices[0].message
            messages.append(message)
            for tool_call in message.tool_calls:
                email = json.loads(tool_call.function.arguments).get("email")
                record_email_tool(email)
                messages.append({"role": "tool", "content": "Email recorded", "tool_call_id": tool_call.id})
            response = openai.chat.completions.create(model=model, messages=messages, tools=tools)
            
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: ajeetkumarmrj@gmail.com
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: Give 2nd last String from a statement
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: to
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)
# Tool called to record an email: the rest of the statement after splitting on first space
# c:\projects\agents\.venv\Lib\site-packages\gradio\routes.py:1541: StarletteDeprecationWarning: 'HTTP_422_UNPROCESSABLE_ENTITY' is deprecated. Use 'HTTP_422_UNPROCESSABLE_CONTENT' instead.
#   return await queue_join_helper(body, request, username)

# %% [markdown]
# # Congratulations!
#
# You just implemented an AI Assistant with Tools.
# And you hand-cranked an Agent Loop, no Agent Framework required.
# That's it!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">1. Add multiple LLM calls! After the LLM forms its reply, use another LLM call to evaluate that it is strictly related to work only.<br/><br/>2. Apply this to your business! Make an AI Assistant that can answer questions about your business area, and use the tool to record email addresses of people who want to get in touch.
#             </span>
#         </td>
#     </tr>
# </table>
